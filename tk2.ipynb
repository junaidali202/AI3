# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidali202/AI3/blob/main/tk2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 2: Stock Portfolio Tracker

# Hardcoded stock prices
stock_prices = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOG": 140,
    "MSFT": 420,
    "AMZN": 180
}

# Display available stocks
print("===== Stock Portfolio Tracker =====")
print("Available stocks:")
print("AAPL - $180")
print("TSLA - $250")
print("GOOG - $140")
print("MSFT - $420")
print("AMZN - $180")

# Get stock name from user
stock_name = input("\nEnter stock name: ").upper()

# Check if stock exists
if stock_name in stock_prices:

    # Get quantity from user
    quantity = int(input("Enter quantity: "))

    # Calculate total investment
    price = stock_prices[stock_name]
    total_investment = price * quantity

    # Display result
    print("\n===== Portfolio Result =====")
    print("Stock:", stock_name)
    print("Price per share: $", price)
    print("Quantity:", quantity)
    print("Total Investment: $", total_investment)

else:
    print("\nSorry, this stock is not available.")
# Out:
# ===== Stock Portfolio Tracker =====
# Available stocks:
# AAPL - $180
# TSLA - $250
# GOOG - $140
# MSFT - $420
# AMZN - $180
#
# Enter stock name: tl
#
# Sorry, this stock is not available.
