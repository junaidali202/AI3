# %% [markdown]
# <a href="https://colab.research.google.com/github/junaidali202/AI3/blob/main/tk3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 3: File Automation
# Move all .jpg files from one folder to another

import os
import shutil

# Source folder
source_folder = "source_folder"

# Destination folder
destination_folder = "destination_folder"

# Create destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Get all files from the source folder
files = os.listdir(source_folder)

# Check each file
for file in files:

    # Check if the file is a JPG image
    if file.lower().endswith(".jpg"):

        # Full path of the source file
        source_path = os.path.join(source_folder, file)

        # Full path of the destination file
        destination_path = os.path.join(destination_folder, file)

        # Move the file
        shutil.move(source_path, destination_path)

        print("Moved:", file)

print("\nAll JPG files have been moved successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1070/1820365134.py in <cell line: 0>()
#      16
#      17 # Get all files from the source folder
# ---> 18 files = os.listdir(source_folder)
#      19
#      20 # Check each file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source_folder'
